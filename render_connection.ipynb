# %%
import psycopg2
import pandas as pd

conn = psycopg2.connect(
    host="dpg-d4j36memcj7s73b90hi0-a.oregon-postgres.render.com",
    database="patients_db_lk5g",
    user="patients_db_lk5g_user",
    password="zZTWFlfZOZXLx9VLCCNoxLfEkxvKe834",
    port=5432
)

df = pd.read_sql_query("SELECT * FROM patients LIMIT 5;", conn)
df
